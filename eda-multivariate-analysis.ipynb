# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# %%
df.head()
# Out:
#   property_type                   society  sector  price_in_crore  \
# 0          flat          smriti apartment      56            0.45
# 1          flat     signature global park      48            0.54
# 2          flat               ats triumph     104            1.85
# 3          flat  pareena laxmi apartments      99            0.32
# 4          flat             m3m woodshire     107            1.40
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7500.0   600.0               Super Built up area 600(55.74 sq.m.)
# 1          7200.0   750.0                     Carpet area: 750 (69.68 sq.m.)
# 2          8078.0  2290.0             Super Built up area 2290(212.75 sq.m.)
# 3          6106.0   524.0  Super Built up area 524(48.68 sq.m.)Carpet are...
# 4          5929.0  2361.0             Super Built up area 2361(219.34 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        1         1       2       3.0         NaN        Old Property
# 1        2         2       2       4.0  North-East  Under Construction
# 2        3         4      3+      14.0        East      Relatively New
# 3        2         2       2       2.0         NaN        New Property
# 4        3         4       0       1.0        East        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                600.0            NaN          NaN           0             0
# 1                  NaN            NaN        750.0           0             0
# 2               2290.0            NaN          NaN           1             1
# 3                524.0            NaN        424.8           0             0
# 4               2361.0            NaN          NaN           0             0
#
#    store room  pooja ghar  others  furnishing_type  luxury_score
# 0           0           0       0                1            57
# 1           0           0       0                1           111
# 2           1           0       0                1           117
# 3           0           0       0                1            50
# 4           0           0       0                1            67

# %% [markdown]
# ### property_type vs price

# %%
sns.barplot(x=df['property_type'], y=df['price_in_crore'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_in_crore'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_in_crore'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_in_crore'>

# %% [markdown]
# ### property_type vs area

# %%
sns.barplot(x=df['property_type'], y=df['built_up_area'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %%
# removing that crazy outlier
df = df[df['built_up_area'] != 737147]

# %%
sns.boxplot(x=df['property_type'], y=df['built_up_area'])
# Out:
# <Axes: xlabel='property_type', ylabel='built_up_area'>

# %% [markdown]
# ### property_type vs price_per_sqft

# %%
sns.barplot(x=df['property_type'], y=df['price_per_sqft'], estimator=np.median)
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
sns.boxplot(x=df['property_type'], y=df['price_per_sqft'])
# Out:
# <Axes: xlabel='property_type', ylabel='price_per_sqft'>

# %%
# check outliers
df[df['price_per_sqft'] > 100000][['property_type','society','sector','price_in_crore','price_per_sqft','area','areaWithType', 'super_built_up_area', 'built_up_area', 'carpet_area']]
# Out:
#      property_type                      society  sector  price_in_crore  \
# 129          house                        ansal      43            1.85
# 388          house                  independent      54            1.60
# 421          house       dlf city plots phase 2      25           10.50
# 449          house         bhim nagar, sector 6       6            0.85
# 710          house                  independent      54            3.75
# 769          house                  independent      21            5.70
# 972          house                  independent      12            6.00
# 1075          flat           ambience caitriona      24           14.00
# 1090         house           vipul tatvam villa      48            7.25
# 1158         house                  independent      17            3.50
# 1242         house            vatika india next      82            7.00
# 1311         house       dlf city plots phase 2      25           10.00
# 1941         house                  independent       3            0.75
# 2006         house                  independent      12            3.50
# 2015         house                   ardee city      52            5.50
# 2085         house                  independent       4            0.60
# 2146         house         eros rosewood villas      49            2.75
# 2224         house                  independent      55            1.45
# 2335         house                  independent      28            4.50
# 2389         house                  independent      24           10.00
# 2517         house                  independent       1           10.00
# 2553         house     unitech uniworld resorts      33           10.00
# 2578         house  unitech nirvana birch court      50            7.10
# 2585         house                    rk excelo      12            0.60
# 2772         house       unitech deerwood chase      50            8.45
# 2791         house     unitech uniworld resorts      33            9.50
# 2913         house                  independent      28            0.65
# 3224         house                  independent      38            8.00
# 3457         house       emaar the palm springs      54           24.00
# 3543         house                dlf the grove      54            5.70
# 3679         house                  independent      23            2.80
# 3733         house               uppal southend      49            6.75
# 3766         house          huda plot sector 38      38            4.30
# 3885         house                  independent      57            8.00
#
#       price_per_sqft   area  \
# 129         308333.0   60.0
# 388         160000.0  100.0
# 421         261194.0  402.0
# 449         126865.0   67.0
# 710         234375.0  160.0
# 769         105751.0  539.0
# 972         315789.0  190.0
# 1075        200000.0  700.0
# 1090        201388.0  360.0
# 1158        218750.0  160.0
# 1242        194444.0  360.0
# 1311        400000.0  250.0
# 1941        138888.0   54.0
# 2006        133079.0  263.0
# 2015        183333.0  300.0
# 2085        105263.0   57.0
# 2146        178571.0  154.0
# 2224        241666.0   60.0
# 2335        125000.0  360.0
# 2389        229885.0  435.0
# 2517        122222.0  818.0
# 2553        181818.0  550.0
# 2578        283333.0  251.0
# 2585        120000.0   50.0
# 2772        235376.0  359.0
# 2791        173992.0  546.0
# 2913        144444.0   45.0
# 3224        230547.0  347.0
# 3457        600000.0  400.0
# 3543        211111.0  270.0
# 3679        161849.0  173.0
# 3733        290948.0  232.0
# 3766        245398.0  175.0
# 3885        266666.0  300.0
#
#                                            areaWithType  super_built_up_area  \
# 129                            Plot area 60(5.57 sq.m.)                  NaN
# 388                           Plot area 100(9.29 sq.m.)                  NaN
# 421                          Plot area 402(37.35 sq.m.)                  NaN
# 449                            Plot area 67(6.22 sq.m.)                  NaN
# 710                          Plot area 160(14.86 sq.m.)                  NaN
# 769                          Plot area 539(50.07 sq.m.)                  NaN
# 972   Plot area 190(17.65 sq.m.)Carpet area: 1600 sq...                  NaN
# 1075                   Built Up area: 700 (65.03 sq.m.)                  NaN
# 1090                         Plot area 360(33.45 sq.m.)                  NaN
# 1158                   Built Up area: 160 (14.86 sq.m.)                  NaN
# 1242  Plot area 360(33.45 sq.m.)Built Up area: 3900 ...                  NaN
# 1311                         Plot area 250(23.23 sq.m.)                  NaN
# 1941                           Plot area 54(5.02 sq.m.)                  NaN
# 2006  Plot area 263(24.43 sq.m.)Built Up area: 4800 ...                  NaN
# 2015                         Plot area 300(27.87 sq.m.)                  NaN
# 2085                            Plot area 57(5.3 sq.m.)                  NaN
# 2146  Plot area 154(14.31 sq.m.)Carpet area: 1650 sq...                  NaN
# 2224                           Plot area 60(5.57 sq.m.)                  NaN
# 2335                   Built Up area: 360 (33.45 sq.m.)                  NaN
# 2389                     Carpet area: 435 (40.41 sq.m.)                  NaN
# 2517                         Plot area 900(83.61 sq.m.)                  NaN
# 2553                          Plot area 550(51.1 sq.m.)                  NaN
# 2578                          Plot area 240(22.3 sq.m.)                  NaN
# 2585  Plot area 50(4.65 sq.m.)Built Up area: 30 sq.f...                  NaN
# 2772                         Plot area 359(33.35 sq.m.)                  NaN
# 2791                         Plot area 546(50.73 sq.m.)                  NaN
# 2913                           Plot area 45(4.18 sq.m.)                  NaN
# 3224  Built Up area: 347 (32.24 sq.m.)Carpet area: 2...                  NaN
# 3457                         Plot area 400(37.16 sq.m.)                  NaN
# 3543                   Built Up area: 270 (25.08 sq.m.)                  NaN
# 3679  Plot area 173(16.07 sq.m.)Built Up area: 160 s...                  NaN
# 3733                         Plot area 232(21.55 sq.m.)                  NaN
# 3766  Plot area 163(15.14 sq.m.)Built Up area: 145 s...                  NaN
# 3885                         Plot area 300(27.87 sq.m.)                  NaN
#
#       built_up_area  carpet_area
# 129            60.0          NaN
# 388           100.0          NaN
# 421           402.0          NaN
# 449            67.0          NaN
# 710           160.0          NaN
# 769           539.0          NaN
# 972             NaN       1600.0
# 1075          700.0          NaN
# 1090          360.0          NaN
# 1158          160.0          NaN
# 1242         3900.0       3743.0
# 1311          250.0          NaN
# 1941           54.0          NaN
# 2006         4800.0       4400.0
# 2015          300.0          NaN
# 2085           57.0          NaN
# 2146            NaN       1650.0
# 2224           60.0          NaN
# 2335          360.0          NaN
# 2389            NaN        435.0
# 2517          900.0          NaN
# 2553          550.0          NaN
# 2578          240.0          NaN
# 2585           30.0         15.0
# 2772          359.0          NaN
# 2791          546.0          NaN
# 2913           45.0          NaN
# 3224          347.0        215.0
# 3457          400.0          NaN
# 3543          270.0          NaN
# 3679          160.0        150.0
# 3733          232.0          NaN
# 3766          145.0          NaN
# 3885          300.0          NaN

# %%
df.head()
# Out:
#   property_type                   society  sector  price_in_crore  \
# 0          flat          smriti apartment      56            0.45
# 1          flat     signature global park      48            0.54
# 2          flat               ats triumph     104            1.85
# 3          flat  pareena laxmi apartments      99            0.32
# 4          flat             m3m woodshire     107            1.40
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7500.0   600.0               Super Built up area 600(55.74 sq.m.)
# 1          7200.0   750.0                     Carpet area: 750 (69.68 sq.m.)
# 2          8078.0  2290.0             Super Built up area 2290(212.75 sq.m.)
# 3          6106.0   524.0  Super Built up area 524(48.68 sq.m.)Carpet are...
# 4          5929.0  2361.0             Super Built up area 2361(219.34 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        1         1       2       3.0         NaN        Old Property
# 1        2         2       2       4.0  North-East  Under Construction
# 2        3         4      3+      14.0        East      Relatively New
# 3        2         2       2       2.0         NaN        New Property
# 4        3         4       0       1.0        East        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                600.0            NaN          NaN           0             0
# 1                  NaN            NaN        750.0           0             0
# 2               2290.0            NaN          NaN           1             1
# 3                524.0            NaN        424.8           0             0
# 4               2361.0            NaN          NaN           0             0
#
#    store room  pooja ghar  others  furnishing_type  luxury_score
# 0           0           0       0                1            57
# 1           0           0       0                1           111
# 2           1           0       0                1           117
# 3           0           0       0                1            50
# 4           0           0       0                1            67

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['bedRoom']))
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
# checking outliers
df[df['bedRoom'] >= 10]
# Out:
#      property_type              society  sector  price_in_crore  \
# 140          house             shivpuri       7            2.80
# 147          house          independent       9            1.25
# 159          house          independent      13            9.00
# 175          house         malibu towne      47            8.50
# 178          house          independent      25             NaN
# ...            ...                  ...     ...             ...
# 3567         house          independent      13            0.50
# 3583         house          independent      55            7.49
# 3733         house       uppal southend      49            6.75
# 3766         house  huda plot sector 38      38            4.30
# 3888         house          independent      43            7.50
#
#       price_per_sqft    area  \
# 140          12444.0  2250.0
# 147           8735.0  1431.0
# 159         100000.0   900.0
# 175          53125.0  1600.0
# 178              NaN     NaN
# ...              ...     ...
# 3567         90909.0    55.0
# 3583         27741.0  2700.0
# 3733        290948.0   232.0
# 3766        245398.0   175.0
# 3888         38760.0  1935.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 140                        Plot area 2250(209.03 sq.m.)       10         7
# 147                         Plot area 159(132.94 sq.m.)       10         6
# 159                          Plot area 900(83.61 sq.m.)       10         5
# 175                  Built Up area: 1600 (148.64 sq.m.)       12        12
# 178   Plot area 250(209.03 sq.m.)Built Up area: 260 ...       12        12
# ...                                                 ...      ...       ...
# 3567                           Plot area 55(5.11 sq.m.)       12         4
# 3583                        Plot area 300(250.84 sq.m.)       12        12
# 3733                         Plot area 232(21.55 sq.m.)       12        12
# 3766  Plot area 163(15.14 sq.m.)Built Up area: 145 s...       13        13
# 3888                        Plot area 215(179.77 sq.m.)       12        12
#
#      balcony  floorNum      facing   agePossession  super_built_up_area  \
# 140        3       1.0         NaN    Old Property                  NaN
# 147       3+       3.0         NaN    Old Property                  NaN
# 159       3+       4.0         NaN    Old Property                  NaN
# 175       3+       4.0       North    New Property                  NaN
# 178       3+       4.0  North-East    New Property                  NaN
# ...      ...       ...         ...             ...                  ...
# 3567       3       4.0         NaN    Old Property                  NaN
# 3583      3+       4.0  South-East  Relatively New                  NaN
# 3733      3+       NaN        West  Moderately Old                  NaN
# 3766      3+       5.0  North-West  Relatively New                  NaN
# 3888      3+       4.0        East    New Property                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 140          2250.0          NaN           1             1           0
# 147          1431.0          NaN           0             0           0
# 159           900.0          NaN           0             0           0
# 175          1600.0          NaN           0             0           0
# 178           260.0        245.0           1             1           0
# ...             ...          ...         ...           ...         ...
# 3567           55.0          NaN           0             0           0
# 3583         2700.0          NaN           1             1           0
# 3733          232.0          NaN           1             1           0
# 3766          145.0          NaN           0             0           0
# 3888         1935.0          NaN           1             1           1
#
#       pooja ghar  others  furnishing_type  luxury_score
# 140            0       1                0             0
# 147            0       0                1             0
# 159            0       0                1             0
# 175            0       0                0            99
# 178            0       1                2           144
# ...          ...     ...              ...           ...
# 3567           0       0                1            15
# 3583           0       0                0            49
# 3733           0       1                0            49
# 3766           0       0                2             7
# 3888           0       0                0            72
#
# [76 rows x 23 columns]

# %%
sns.barplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
sns.boxplot(x=df['property_type'],y=df['floorNum'])
# Out:
# <Axes: xlabel='property_type', ylabel='floorNum'>

# %%
# checking for outliers
df[(df['property_type'] == 'house') & (df['floorNum'] > 10)]
# Out:
#      property_type                  society  sector  price_in_crore  \
# 205          house           dlf the arbour      63            8.50
# 242          house              greenopolis      89            0.70
# 303          house      satya the hermitage     103            3.15
# 388          house              independent      54            1.60
# 933          house           ats tourmaline     109            1.87
# 985          house              spaze privy      72            3.09
# 1037         house      ireo victory valley      67            8.00
# 1106         house          godrej meridien     106            5.60
# 1573         house  indiabulls centrum park     103            3.25
# 1727         house   vatika the seven lamps      82            1.60
# 2496         house              spaze privy      72            3.10
# 2738         house        suncity avenue 76      76            0.75
# 3436         house              independent      92            1.80
# 3474         house         suncity township      54            2.00
# 3511         house               ninex city      76            1.75
#
#       price_per_sqft    area  \
# 205          21519.0  3950.0
# 242           5397.0  1297.0
# 303           6702.0  4700.0
# 388         160000.0   100.0
# 933           8697.0  2150.0
# 985           6981.0  4426.0
# 1037         22222.0  3600.0
# 1106         14000.0  4000.0
# 1573          8125.0  4000.0
# 1727          6597.0  2425.0
# 2496          8486.0  3653.0
# 2738         10067.0   745.0
# 3436          7627.0  2360.0
# 3474         30968.0   646.0
# 3511          6250.0  2800.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 205                  Built Up area: 3950 (366.97 sq.m.)        4         4
# 242                   Built Up area: 1297 (120.5 sq.m.)        2         2
# 303                  Built Up area: 4700 (436.64 sq.m.)        4         5
# 388                           Plot area 100(9.29 sq.m.)        3         2
# 933                  Built Up area: 2150 (199.74 sq.m.)        3         4
# 985   Built Up area: 3653 (339.37 sq.m.)Carpet area:...        5         5
# 1037                        Plot area 400(334.45 sq.m.)        6         7
# 1106                       Plot area 4000(371.61 sq.m.)        5         4
# 1573                       Plot area 4000(371.61 sq.m.)        4         3
# 1727                       Plot area 2425(225.29 sq.m.)        4         4
# 2496                       Plot area 3653(339.37 sq.m.)        5         5
# 2738  Plot area 745(69.21 sq.m.)Built Up area: 745 s...        2         2
# 3436                 Built Up area: 2360 (219.25 sq.m.)        4         5
# 3474  Plot area 60Built Up area: 60 sq.m.Carpet area...        9         9
# 3511                   Carpet area: 2800 (260.13 sq.m.)        4         4
#
#      balcony  floorNum      facing       agePossession  super_built_up_area  \
# 205       3+      27.0         NaN           Undefined                  NaN
# 242        2      14.0  North-East           Undefined                  NaN
# 303        0      12.0        East           Undefined                  NaN
# 388        2      41.0         NaN      Relatively New                  NaN
# 933        0      12.0         NaN           Undefined                  NaN
# 985       3+      14.0        East      Relatively New                  NaN
# 1037      3+      51.0  North-East      Moderately Old                  NaN
# 1106      3+      33.0  North-East        New Property                  NaN
# 1573      3+      20.0         NaN  Under Construction                  NaN
# 1727      3+      16.0       North      Moderately Old                  NaN
# 2496      3+      21.0         NaN      Relatively New                  NaN
# 2738       2      11.0  North-East        New Property                  NaN
# 3436       0      13.0         NaN           Undefined                  NaN
# 3474       3      11.0       North      Relatively New                  NaN
# 3511       0      14.0         NaN           Undefined                  NaN
#
#       built_up_area  carpet_area  study room  servant room  store room  \
# 205          3950.0          NaN           0             0           0
# 242          1297.0          NaN           0             0           0
# 303          4700.0          NaN           0             0           0
# 388           100.0          NaN           0             0           0
# 933          2150.0          NaN           0             0           0
# 985          3653.0       2922.0           0             1           0
# 1037         3600.0          NaN           1             1           0
# 1106         4000.0          NaN           1             1           1
# 1573         4000.0          NaN           0             0           0
# 1727         2425.0          NaN           0             1           0
# 2496         3653.0          NaN           0             0           0
# 2738          745.0          NaN           0             0           0
# 3436         2360.0          NaN           0             0           0
# 3474           60.0         59.0           0             1           0
# 3511            NaN       2800.0           0             0           0
#
#       pooja ghar  others  furnishing_type  luxury_score
# 205            0       0                1            61
# 242            0       0                1             0
# 303            0       0                1            61
# 388            0       0                1             0
# 933            0       0                1             0
# 985            0       0                0            33
# 1037           0       0                0            49
# 1106           0       0                1           151
# 1573           0       0                1            51
# 1727           0       0                1            94
# 2496           0       0                1             0
# 2738           0       0                1            40
# 3436           0       0                1             0
# 3474           0       0                2             7
# 3511           0       0                1             0

# %%
# conclusion houses(villa) but in appartments

# %%
df.head()
# Out:
#   property_type                   society  sector  price_in_crore  \
# 0          flat          smriti apartment      56            0.45
# 1          flat     signature global park      48            0.54
# 2          flat               ats triumph     104            1.85
# 3          flat  pareena laxmi apartments      99            0.32
# 4          flat             m3m woodshire     107            1.40
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7500.0   600.0               Super Built up area 600(55.74 sq.m.)
# 1          7200.0   750.0                     Carpet area: 750 (69.68 sq.m.)
# 2          8078.0  2290.0             Super Built up area 2290(212.75 sq.m.)
# 3          6106.0   524.0  Super Built up area 524(48.68 sq.m.)Carpet are...
# 4          5929.0  2361.0             Super Built up area 2361(219.34 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        1         1       2       3.0         NaN        Old Property
# 1        2         2       2       4.0  North-East  Under Construction
# 2        3         4      3+      14.0        East      Relatively New
# 3        2         2       2       2.0         NaN        New Property
# 4        3         4       0       1.0        East        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                600.0            NaN          NaN           0             0
# 1                  NaN            NaN        750.0           0             0
# 2               2290.0            NaN          NaN           1             1
# 3                524.0            NaN        424.8           0             0
# 4               2361.0            NaN          NaN           0             0
#
#    store room  pooja ghar  others  furnishing_type  luxury_score
# 0           0           0       0                1            57
# 1           0           0       0                1           111
# 2           1           0       0                1           117
# 3           0           0       0                1            50
# 4           0           0       0                1            67

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['agePossession']))
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='agePossession',values='price_in_crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='agePossession', ylabel='property_type'>

# %%
plt.figure(figsize=(15,4))
sns.heatmap(pd.pivot_table(df,index='property_type',columns='bedRoom',values='price_in_crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='bedRoom', ylabel='property_type'>

# %%
sns.heatmap(pd.crosstab(df['property_type'],df['furnishing_type']))
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.heatmap(pd.pivot_table(df,index='property_type',columns='furnishing_type',values='price_in_crore',aggfunc='mean'),annot=True)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='property_type'>

# %%
sns.barplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
sns.boxplot(x=df['property_type'],y=df['luxury_score'])
# Out:
# <Axes: xlabel='property_type', ylabel='luxury_score'>

# %%
df.head()
# Out:
#   property_type                   society  sector  price_in_crore  \
# 0          flat          smriti apartment      56            0.45
# 1          flat     signature global park      48            0.54
# 2          flat               ats triumph     104            1.85
# 3          flat  pareena laxmi apartments      99            0.32
# 4          flat             m3m woodshire     107            1.40
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7500.0   600.0               Super Built up area 600(55.74 sq.m.)
# 1          7200.0   750.0                     Carpet area: 750 (69.68 sq.m.)
# 2          8078.0  2290.0             Super Built up area 2290(212.75 sq.m.)
# 3          6106.0   524.0  Super Built up area 524(48.68 sq.m.)Carpet are...
# 4          5929.0  2361.0             Super Built up area 2361(219.34 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        1         1       2       3.0         NaN        Old Property
# 1        2         2       2       4.0  North-East  Under Construction
# 2        3         4      3+      14.0        East      Relatively New
# 3        2         2       2       2.0         NaN        New Property
# 4        3         4       0       1.0        East        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                600.0            NaN          NaN           0             0
# 1                  NaN            NaN        750.0           0             0
# 2               2290.0            NaN          NaN           1             1
# 3                524.0            NaN        424.8           0             0
# 4               2361.0            NaN          NaN           0             0
#
#    store room  pooja ghar  others  furnishing_type  luxury_score
# 0           0           0       0                1            57
# 1           0           0       0                1           111
# 2           1           0       0                1           117
# 3           0           0       0                1            50
# 4           0           0       0                1            67

# %%
# sector analysis
plt.figure(figsize=(15,6))
sns.heatmap(pd.crosstab(df['property_type'],df['sector'].sort_index()))
# Out:
# <Axes: xlabel='sector', ylabel='property_type'>

# %%
# sector analysis
import re
# Group by 'sector' and calculate the average price
avg_price_per_sector = df.groupby('sector')['price_in_crore'].mean().reset_index()

# Function to extract sector numbers
def extract_sector_number(sector_name):
    match = re.search(r'\d+', sector_name)
    if match:
        return int(match.group())
    else:
        return float('inf')  # Return a large number for non-numbered sectors

avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sector_sorted_by_sector.set_index('sector')[['price']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Average Price per Sector (Sorted by Sector Number)')
plt.xlabel('Average Price')
plt.ylabel('Sector')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 14
#      11     else:
#      12         return float('inf')  # Return a large number for non-numbered sectors
# ---> 14 avg_price_per_sector['sector_number'] = avg_price_per_sector['sector'].apply(extract_sector_number)
#      16 # Sort by sector number
#      17 avg_price_per_sector_sorted_by_sector = avg_price_per_sector.sort_values(by='sector_number')
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[32], line 8, in extract_sector_number(sector_name)
#       7 def extract_sector_number(sector_name):
# ----> 8     match = re.search(r'\d+', sector_name)
#       9     if match:
#      10         return int(match.group())
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'int'

# %%
avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()

avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)

# Sort by sector number
avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(avg_price_per_sqft_sector_sorted_by_sector.set_index('sector')[['price_per_sqft']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 avg_price_per_sqft_sector = df.groupby('sector')['price_per_sqft'].mean().reset_index()
# ----> 3 avg_price_per_sqft_sector['sector_number'] = avg_price_per_sqft_sector['sector'].apply(extract_sector_number)
#       5 # Sort by sector number
#       6 avg_price_per_sqft_sector_sorted_by_sector = avg_price_per_sqft_sector.sort_values(by='sector_number')
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[32], line 8, in extract_sector_number(sector_name)
#       7 def extract_sector_number(sector_name):
# ----> 8     match = re.search(r'\d+', sector_name)
#       9     if match:
#      10         return int(match.group())
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'int'

# %%
luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()

luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)

# Sort by sector number
luxury_score_sector = luxury_score.sort_values(by='sector_number')

# Plot the heatmap
plt.figure(figsize=(5, 25))
sns.heatmap(luxury_score_sector.set_index('sector')[['luxury_score']], annot=True, fmt=".2f", linewidths=.5)
plt.title('Sector (Sorted by Sector Number)')
plt.xlabel('Average Price per sqft')
plt.ylabel('Sector')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 luxury_score = df.groupby('sector')['luxury_score'].mean().reset_index()
# ----> 3 luxury_score['sector_number'] = luxury_score['sector'].apply(extract_sector_number)
#       5 # Sort by sector number
#       6 luxury_score_sector = luxury_score.sort_values(by='sector_number')
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)   4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
#    4818     Invoke function on values of Series.
#    4819
#    (...)   4934     dtype: float64
#    4935     """
#    4936     return SeriesApply(
#    4937         self,
#    4938         func,
#    4939         convert_dtype=convert_dtype,
#    4940         by_row=by_row,
#    4941         args=args,
#    4942         kwargs=kwargs,
# -> 4943     ).apply()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[32], line 8, in extract_sector_number(sector_name)
#       7 def extract_sector_number(sector_name):
# ----> 8     match = re.search(r'\d+', sector_name)
#       9     if match:
#      10         return int(match.group())
#
# File c:\Users\palas\AppData\Local\Programs\Python\Python313\Lib\re\__init__.py:177, in search(pattern, string, flags)
#     174 def search(pattern, string, flags=0):
#     175     """Scan through string looking for a match to the pattern, returning
#     176     a Match object, or None if no match was found."""
# --> 177     return _compile(pattern, flags).search(string)
#
# TypeError: expected string or bytes-like object, got 'int'

# %%
df.head()
# Out:
#   property_type                      society      sector  price  \
# 0          flat      signature global park 4   sector 36   0.82
# 1          flat             smart world gems   sector 89   0.95
# 2          flat                pyramid elite   sector 86   0.46
# 3          flat       breez global hill view  sohna road   0.32
# 4          flat  bestech park view sanskruti   sector 92   1.60
#
#    price_per_sqft     area                                       areaWithType  \
# 0          7585.0   1081.0  Super Built up area 1081(100.43 sq.m.)Carpet a...
# 1          8600.0   1105.0                   Carpet area: 1103 (102.47 sq.m.)
# 2            79.0  58228.0                 Carpet area: 58141 (5401.48 sq.m.)
# 3          5470.0    585.0  Built Up area: 1000 (92.9 sq.m.)Carpet area: 5...
# 4          8020.0   1995.0  Super Built up area 1995(185.34 sq.m.)Built Up...
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        3         2       2       2.0         NaN        New Property
# 1        2         2       2       4.0         NaN        New Property
# 2        2         2       1       0.0         NaN  Under Construction
# 3        2         2       1      17.0         NaN        New Property
# 4        3         4      3+      10.0  North-West      Relatively New
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0               1081.0            NaN        650.0           0             0
# 1                  NaN            NaN       1103.0           1             1
# 2                  NaN            NaN      58141.0           0             0
# 3                  NaN         1000.0        585.0           0             0
# 4               1995.0         1615.0       1476.0           0             1
#
#    store room  pooja room  others  furnishing_type  luxury_score
# 0           0           0       0                0             8
# 1           0           0       0                0            38
# 2           0           0       0                0            15
# 3           0           0       0                0            49
# 4           0           0       1                1           174

# %% [markdown]
# ### price

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price_in_crore'],hue=df['bedRoom'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.scatterplot(df[df['area']<10000]['area'],df['price_in_crore'],hue=df['bedRoom'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price_in_crore'],hue=df['agePossession'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 sns.scatterplot(df[df['area']<10000]['area'],df['price_in_crore'],hue=df['agePossession'])
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df[df['area']<10000]['area'],df['price'],hue=df['furnishing_type'].astype('category'))
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
sns.barplot(x=df['bedRoom'],y=df['price_in_crore'],estimator=np.median)
# Out:
# <Axes: xlabel='bedRoom', ylabel='price_in_crore'>

# %%
sns.barplot(x=df['agePossession'],y=df['price_in_crore'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['agePossession'],y=df['area'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=df['furnishing_type'],y=df['price_in_crore'],estimator=np.median)
# Out:
# <Axes: xlabel='furnishing_type', ylabel='price_in_crore'>

# %% [markdown]
# ### correlation

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only=True)['price_in_crore'].sort_values(ascending=False)
# Out:
# price_in_crore         1.000000
# super_built_up_area    0.770297
# bathroom               0.553212
# built_up_area          0.511157
# bedRoom                0.483861
# servant room           0.404901
# price_per_sqft         0.382577
# store room             0.306469
# study room             0.258405
# luxury_score           0.105506
# area                  -0.000251
# others                -0.005261
# carpet_area           -0.010288
# floorNum              -0.086549
# furnishing_type       -0.138647
# sector                -0.169354
# pooja ghar                  NaN
# Name: price_in_crore, dtype: float64

# %%
df.head()
# Out:
#   property_type                   society  sector  price_in_crore  \
# 0          flat          smriti apartment      56            0.45
# 1          flat     signature global park      48            0.54
# 2          flat               ats triumph     104            1.85
# 3          flat  pareena laxmi apartments      99            0.32
# 4          flat             m3m woodshire     107            1.40
#
#    price_per_sqft    area                                       areaWithType  \
# 0          7500.0   600.0               Super Built up area 600(55.74 sq.m.)
# 1          7200.0   750.0                     Carpet area: 750 (69.68 sq.m.)
# 2          8078.0  2290.0             Super Built up area 2290(212.75 sq.m.)
# 3          6106.0   524.0  Super Built up area 524(48.68 sq.m.)Carpet are...
# 4          5929.0  2361.0             Super Built up area 2361(219.34 sq.m.)
#
#    bedRoom  bathroom balcony  floorNum      facing       agePossession  \
# 0        1         1       2       3.0         NaN        Old Property
# 1        2         2       2       4.0  North-East  Under Construction
# 2        3         4      3+      14.0        East      Relatively New
# 3        2         2       2       2.0         NaN        New Property
# 4        3         4       0       1.0        East        New Property
#
#    super_built_up_area  built_up_area  carpet_area  study room  servant room  \
# 0                600.0            NaN          NaN           0             0
# 1                  NaN            NaN        750.0           0             0
# 2               2290.0            NaN          NaN           1             1
# 3                524.0            NaN        424.8           0             0
# 4               2361.0            NaN          NaN           0             0
#
#    store room  pooja ghar  others  furnishing_type  luxury_score
# 0           0           0       0                1            57
# 1           0           0       0                1           111
# 2           1           0       0                1           117
# 3           0           0       0                1            50
# 4           0           0       0                1            67

# %%
sns.pairplot(df)
